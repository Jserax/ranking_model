# %%
# !pip install gdown einops
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 635.1 kB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.13.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: einops
# Successfully installed einops-0.8.0

# %%
# !gdown 1viFKqtYTtTiP9_EdBXVpCmWbNmxDiXWG
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1viFKqtYTtTiP9_EdBXVpCmWbNmxDiXWG
# From (redirected): https://drive.google.com/uc?id=1viFKqtYTtTiP9_EdBXVpCmWbNmxDiXWG&confirm=t&uuid=f00608a6-0d27-4246-8ba3-457e350e0ae7
# To: /content/intern_task.csv
# 100% 222M/222M [00:01<00:00, 162MB/s]

# %%
import torch
from tqdm.notebook import tqdm

from dataset import Dataset, split_data
from metrics import ndcgk
from model import Encoder
from scheduler import CosineScheduler

epochs = 80
warmup_epochs = 16
decay_epochs = 8
batch_size = 64
start_lr = 1e-4
max_lr = 6e-3
min_lr = 1e-7
weight_decay = 0.05
grad_clip = 1.0
device = "cuda" if torch.cuda.is_available() else "cpu"

model = Encoder().to(device)
train_data, test_data = split_data("/content/intern_task.csv", 0.1, 42)
train_ds = Dataset(train_data, batch_size=batch_size)
test_ds = Dataset(test_data, batch_size=batch_size)

epoch_iters = len(train_ds)
optimizer = torch.optim.AdamW(model.parameters(), weight_decay)
scaler = torch.cuda.amp.GradScaler()
criterion = torch.nn.L1Loss()
scheduler = CosineScheduler(
    optimizer,
    warmup_epochs * epoch_iters,
    (epochs - decay_epochs) * epoch_iters,
    start_lr,
    min_lr,
    max_lr,
)

for epoch in tqdm(range(1, epochs + 1)):
    train_loss = 0.0
    ndcg = torch.empty((0,))
    for iterations, (x, y, weights) in enumerate(train_ds.batch(), start=1):
        x = x.to(device)
        y = y.to(device)
        weights = weights.to(device)
        scheduler.step()
        optimizer.zero_grad()
        pred = weights * model(x)
        loss = criterion(pred, y)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
        optimizer.step()
        train_loss += loss.item()
        with torch.no_grad():
            ndcg = torch.cat([ndcg, ndcgk(y.cpu(), pred.cpu(), k=5, rel="exp2")])
    ndcg = ndcg.mean().item()
    print(
        f"Epochs: {epoch}/{epochs} | Train_loss {train_loss / iterations:.4f} | ndcg {ndcg:.4f}"
    )
test_loss = 0.0
ndcg = torch.empty((0,))
model.eval()
for iterations, (x, y, weights) in enumerate(train_ds.batch(), start=1):
    with torch.no_grad():
        x = x.to(device)
        y = y.to(device)
        weights = weights.to(device)
        pred = weights * model(x)
        loss = criterion(pred, y)
        test_loss += loss.item()
        ndcg = torch.cat([ndcg, ndcgk(y.cpu(), pred.cpu(), k=5, rel="exp2")])
ndcg = ndcg.mean().item()
print(f"Test loss {test_loss / iterations:.4f} | ndcg {ndcg:.4f}")
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# Epochs: 1/80 | Train_loss 0.2532 | ndcg 0.2019
# Epochs: 2/80 | Train_loss 0.2409 | ndcg 0.2059
# Epochs: 3/80 | Train_loss 0.2425 | ndcg 0.2314
# Epochs: 4/80 | Train_loss 0.2557 | ndcg 0.2194
# Epochs: 5/80 | Train_loss 0.2475 | ndcg 0.2375
# Epochs: 6/80 | Train_loss 0.2416 | ndcg 0.2548
# Epochs: 7/80 | Train_loss 0.2615 | ndcg 0.2494
# Epochs: 8/80 | Train_loss 0.2573 | ndcg 0.2370
# Epochs: 9/80 | Train_loss 0.2485 | ndcg 0.2544
# Epochs: 10/80 | Train_loss 0.2467 | ndcg 0.2459
# Epochs: 11/80 | Train_loss 0.2446 | ndcg 0.2404
# Epochs: 12/80 | Train_loss 0.2369 | ndcg 0.2587
# Epochs: 13/80 | Train_loss 0.2405 | ndcg 0.2614
# Epochs: 14/80 | Train_loss 0.2416 | ndcg 0.2799
# Epochs: 15/80 | Train_loss 0.2487 | ndcg 0.2588
# Epochs: 16/80 | Train_loss 0.2334 | ndcg 0.2662
# Epochs: 17/80 | Train_loss 0.2426 | ndcg 0.2596
# Epochs: 18/80 | Train_loss 0.2418 | ndcg 0.2616
# Epochs: 19/80 | Train_loss 0.2436 | ndcg 0.2748
# Epochs: 20/80 | Train_loss 0.2505 | ndcg 0.2625
# Epochs: 21/80 | Train_loss 0.2506 | ndcg 0.2645
# Epochs: 22/80 | Train_loss 0.2425 | ndcg 0.2601
# Epochs: 23/80 | Train_loss 0.2399 | ndcg 0.2640
# Epochs: 24/80 | Train_loss 0.2388 | ndcg 0.2628
# Epochs: 25/80 | Train_loss 0.2327 | ndcg 0.2697
# Epochs: 26/80 | Train_loss 0.2359 | ndcg 0.2698
# Epochs: 27/80 | Train_loss 0.2413 | ndcg 0.2700
# Epochs: 28/80 | Train_loss 0.2391 | ndcg 0.2743
# Epochs: 29/80 | Train_loss 0.2346 | ndcg 0.2715
# Epochs: 30/80 | Train_loss 0.2271 | ndcg 0.2749
# Epochs: 31/80 | Train_loss 0.2270 | ndcg 0.2810
# Epochs: 32/80 | Train_loss 0.2250 | ndcg 0.2807
# Epochs: 33/80 | Train_loss 0.2428 | ndcg 0.2716
# Epochs: 34/80 | Train_loss 0.2325 | ndcg 0.2838
# Epochs: 35/80 | Train_loss 0.2213 | ndcg 0.2758
# Epochs: 36/80 | Train_loss 0.2246 | ndcg 0.2797
# Epochs: 37/80 | Train_loss 0.2211 | ndcg 0.2801
# Epochs: 38/80 | Train_loss 0.2239 | ndcg 0.2785
# Epochs: 39/80 | Train_loss 0.2225 | ndcg 0.2813
# Epochs: 40/80 | Train_loss 0.2325 | ndcg 0.2869
# Epochs: 41/80 | Train_loss 0.2264 | ndcg 0.2896
# Epochs: 42/80 | Train_loss 0.2150 | ndcg 0.2841
# Epochs: 43/80 | Train_loss 0.2169 | ndcg 0.2912
# Epochs: 44/80 | Train_loss 0.2178 | ndcg 0.2869
# Epochs: 45/80 | Train_loss 0.2207 | ndcg 0.2870
# Epochs: 46/80 | Train_loss 0.2232 | ndcg 0.2890
# Epochs: 47/80 | Train_loss 0.2280 | ndcg 0.2853
# Epochs: 48/80 | Train_loss 0.2132 | ndcg 0.2963
# Epochs: 49/80 | Train_loss 0.2170 | ndcg 0.2960
# Epochs: 50/80 | Train_loss 0.2224 | ndcg 0.2853
# Epochs: 51/80 | Train_loss 0.2172 | ndcg 0.2906
# Epochs: 52/80 | Train_loss 0.2199 | ndcg 0.2971
# Epochs: 53/80 | Train_loss 0.2104 | ndcg 0.2996
# Epochs: 54/80 | Train_loss 0.2039 | ndcg 0.3029
# Epochs: 55/80 | Train_loss 0.2081 | ndcg 0.3035
# Epochs: 56/80 | Train_loss 0.2046 | ndcg 0.3048
# Epochs: 57/80 | Train_loss 0.2091 | ndcg 0.3040
# Epochs: 58/80 | Train_loss 0.2106 | ndcg 0.3081
# Epochs: 59/80 | Train_loss 0.2139 | ndcg 0.3015
# Epochs: 60/80 | Train_loss 0.2184 | ndcg 0.3033
# Epochs: 61/80 | Train_loss 0.2080 | ndcg 0.3034
# Epochs: 62/80 | Train_loss 0.2079 | ndcg 0.3061
# Epochs: 63/80 | Train_loss 0.2107 | ndcg 0.3024
# Epochs: 64/80 | Train_loss 0.2203 | ndcg 0.2997
# Epochs: 65/80 | Train_loss 0.1971 | ndcg 0.2990
# Epochs: 66/80 | Train_loss 0.2052 | ndcg 0.3007
# Epochs: 67/80 | Train_loss 0.2014 | ndcg 0.3039
# Epochs: 68/80 | Train_loss 0.1990 | ndcg 0.3058
# Epochs: 69/80 | Train_loss 0.2045 | ndcg 0.3036
# Epochs: 70/80 | Train_loss 0.2054 | ndcg 0.3025
# Epochs: 71/80 | Train_loss 0.1998 | ndcg 0.3038
# Epochs: 72/80 | Train_loss 0.2006 | ndcg 0.3040
# Epochs: 73/80 | Train_loss 0.2053 | ndcg 0.3042
# Epochs: 74/80 | Train_loss 0.1991 | ndcg 0.3046
# Epochs: 75/80 | Train_loss 0.2042 | ndcg 0.3022
# Epochs: 76/80 | Train_loss 0.2098 | ndcg 0.3019
# Epochs: 77/80 | Train_loss 0.2035 | ndcg 0.3052
# Epochs: 78/80 | Train_loss 0.1963 | ndcg 0.3041
# Epochs: 79/80 | Train_loss 0.2085 | ndcg 0.3033
# Epochs: 80/80 | Train_loss 0.2033 | ndcg 0.3034
# Test loss 0.1980 | ndcg 0.3039

# %%
import torch
from tqdm.notebook import tqdm

from dataset import Dataset, split_data
from metrics import ndcgk, dcg
from model import Encoder
from scheduler import CosineScheduler

epochs = 80
warmup_epochs = 16
decay_epochs = 8
batch_size = 64
start_lr = 1e-4
max_lr = 6e-3
min_lr = 1e-7
weight_decay = 0.05
grad_clip = 1.0
device = "cuda" if torch.cuda.is_available() else "cpu"

model = Encoder().to(device)
train_data, test_data = split_data("/content/intern_task.csv", 0.1, 42)
train_ds = Dataset(train_data, batch_size=batch_size)
test_ds = Dataset(test_data, batch_size=batch_size)

epoch_iters = len(train_ds)
optimizer = torch.optim.AdamW(model.parameters(), weight_decay)
scaler = torch.cuda.amp.GradScaler()
criterion = torch.nn.L1Loss()
scheduler = CosineScheduler(
    optimizer,
    warmup_epochs * epoch_iters,
    (epochs - decay_epochs) * epoch_iters,
    start_lr,
    min_lr,
    max_lr,
)

for epoch in tqdm(range(1, epochs + 1)):
    ndcg = torch.empty((0,))
    for iterations, (x, y, weights) in enumerate(train_ds.batch(), start=1):
        x = x.to(device)
        y = y.to(device)
        weights = weights.to(device)
        scheduler.step()
        optimizer.zero_grad()
        pred = weights * model(x)

        # LambdaRank gradient computation
        sigma = 1.0
        N = 1 / (dcg(y.cpu(), y.cpu(), x.size(1), "exp2").sum(-1) + 1e-10)
        rank_order = pred.argsort(descending=True, dim=-1).argsort(dim=-1) + 1

        pos_pairs_score_diff = 1.0 + torch.exp(
            sigma * (pred.unsqueeze(1) - pred.unsqueeze(-1))
        )

        rel_diff = y.unsqueeze(1) - y.unsqueeze(-1)
        pos_pairs = (rel_diff > 0.0).type(torch.float32)
        neg_pairs = (rel_diff < 0.0).type(torch.float32)
        Sij = pos_pairs - neg_pairs

        gain_diff = torch.pow(2, y.unsqueeze(1)) - torch.pow(2, y.unsqueeze(-1))
        decay_diff = 1.0 / torch.log2(rank_order.unsqueeze(1) + 1.0) - 1.0 / torch.log2(
            rank_order.unsqueeze(-1) + 1.0
        )
        delta_ndcg = torch.abs(N.view(-1, 1, 1).to(device) * gain_diff * decay_diff)
        lambda_update = (
            sigma * (0.5 * (1 - Sij) - 1 / pos_pairs_score_diff) * delta_ndcg
        )

        pred.backward(torch.sum(lambda_update, 1))
        torch.nn.utils.clip_grad_norm_(model.parameters(), grad_clip)
        optimizer.step()
        with torch.no_grad():
            ndcg = torch.cat([ndcg, ndcgk(y.cpu(), pred.cpu(), k=5, rel="exp2")])
    ndcg = ndcg.mean().item()
    print(f"Epochs: {epoch}/{epochs} | ndcg {ndcg:.4f}")
test_loss = 0.0
ndcg = torch.empty((0,))
model.eval()
for iterations, (x, y, weights) in enumerate(train_ds.batch(), start=1):
    with torch.no_grad():
        x = x.to(device)
        y = y.to(device)
        weights = weights.to(device)
        pred = weights * model(x)
        ndcg = torch.cat([ndcg, ndcgk(y.cpu(), pred.cpu(), k=5, rel="exp2")])
ndcg = ndcg.mean().item()
print(f"Test Ndcg {ndcg:.4f}")
# Out:
#   0%|          | 0/80 [00:00<?, ?it/s]
# Epochs: 1/80 | ndcg 0.1507
# Epochs: 2/80 | ndcg 0.1856
# Epochs: 3/80 | ndcg 0.2059
# Epochs: 4/80 | ndcg 0.2305
# Epochs: 5/80 | ndcg 0.2457
# Epochs: 6/80 | ndcg 0.2555
# Epochs: 7/80 | ndcg 0.2619
# Epochs: 8/80 | ndcg 0.2719
# Epochs: 9/80 | ndcg 0.2800
# Epochs: 10/80 | ndcg 0.2915
# Epochs: 11/80 | ndcg 0.2919
# Epochs: 12/80 | ndcg 0.2855
# Epochs: 13/80 | ndcg 0.2934
# Epochs: 14/80 | ndcg 0.2973
# Epochs: 15/80 | ndcg 0.3078
# Epochs: 16/80 | ndcg 0.3129
# Epochs: 17/80 | ndcg 0.3205
# Epochs: 18/80 | ndcg 0.3259
# Epochs: 19/80 | ndcg 0.3158
# Epochs: 20/80 | ndcg 0.3212
# Epochs: 21/80 | ndcg 0.3338
# Epochs: 22/80 | ndcg 0.3210
# Epochs: 23/80 | ndcg 0.3272
# Epochs: 24/80 | ndcg 0.3220
# Epochs: 25/80 | ndcg 0.3386
# Epochs: 26/80 | ndcg 0.3299
# Epochs: 27/80 | ndcg 0.3365
# Epochs: 28/80 | ndcg 0.3252
# Epochs: 29/80 | ndcg 0.3350
# Epochs: 30/80 | ndcg 0.3416
# Epochs: 31/80 | ndcg 0.3354
# Epochs: 32/80 | ndcg 0.3378
# Epochs: 33/80 | ndcg 0.3330
# Epochs: 34/80 | ndcg 0.3241
# Epochs: 35/80 | ndcg 0.3358
# Epochs: 36/80 | ndcg 0.3425
# Epochs: 37/80 | ndcg 0.3436
# Epochs: 38/80 | ndcg 0.3403
# Epochs: 39/80 | ndcg 0.3535
# Epochs: 40/80 | ndcg 0.3378
# Epochs: 41/80 | ndcg 0.3535
# Epochs: 42/80 | ndcg 0.3483
# Epochs: 43/80 | ndcg 0.3505
# Epochs: 44/80 | ndcg 0.3589
# Epochs: 45/80 | ndcg 0.3657
# Epochs: 46/80 | ndcg 0.3572
# Epochs: 47/80 | ndcg 0.3492
# Epochs: 48/80 | ndcg 0.3609
# Epochs: 49/80 | ndcg 0.3497
# Epochs: 50/80 | ndcg 0.3703
# Epochs: 51/80 | ndcg 0.3707
# Epochs: 52/80 | ndcg 0.3603
# Epochs: 53/80 | ndcg 0.3603
# Epochs: 54/80 | ndcg 0.3663
# Epochs: 55/80 | ndcg 0.3683
# Epochs: 56/80 | ndcg 0.3640
# Epochs: 57/80 | ndcg 0.3726
# Epochs: 58/80 | ndcg 0.3726
# Epochs: 59/80 | ndcg 0.3726
# Epochs: 60/80 | ndcg 0.3696
# Epochs: 61/80 | ndcg 0.3739
# Epochs: 62/80 | ndcg 0.3771
# Epochs: 63/80 | ndcg 0.3764
# Epochs: 64/80 | ndcg 0.3746
# Epochs: 65/80 | ndcg 0.3753
# Epochs: 66/80 | ndcg 0.3754
# Epochs: 67/80 | ndcg 0.3764
# Epochs: 68/80 | ndcg 0.3745
# Epochs: 69/80 | ndcg 0.3749
# Epochs: 70/80 | ndcg 0.3779
# Epochs: 71/80 | ndcg 0.3770
# Epochs: 72/80 | ndcg 0.3766
# Epochs: 73/80 | ndcg 0.3769
# Epochs: 74/80 | ndcg 0.3776
# Epochs: 75/80 | ndcg 0.3776
# Epochs: 76/80 | ndcg 0.3771
# Epochs: 77/80 | ndcg 0.3766
# Epochs: 78/80 | ndcg 0.3767
# Epochs: 79/80 | ndcg 0.3767
# Epochs: 80/80 | ndcg 0.3767
# Test Ndcg 0.3765
